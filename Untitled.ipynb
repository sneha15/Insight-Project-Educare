# %%
import pandas as pd
import glob
import time
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
init_notebook_mode(connected=True)
from plotly.graph_objs import *
import us
import os
from iso3166 import countries

perm_data = pd.read_pickle('perm')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
perm_data_15 = perm_data[pd.DatetimeIndex(perm_data['DECISION_DATE']).year == 2015]
perm_data_15.head()
# Out:
#         CASE_NUMBER DECISION_DATE        CASE_STATUS CASE_RECEIVED_DATE  \
# 15 0  A-14220-96665    2015-02-03  Certified-Expired         2014-09-10
#    1  A-14220-96720    2015-01-12  Certified-Expired         2014-08-08
#    3  A-14206-92509    2015-03-10  Certified-Expired         2014-10-19
#    4  A-14202-90786    2015-01-07  Certified-Expired         2014-08-25
#    6  A-14202-90920    2015-01-26  Certified-Expired         2014-07-25
#
#                             EMPLOYER_NAME  \
# 15 0               UNION PACIFIC RAILROAD
#    1                   VST CONSULTING INC
#    3                    INTEL CORPORATION
#    4           NET ESOLUTIONS CORPORATION
#    6  BURGER REHABILITATION SYSTEMS, INC.
#
#                            PW_JOB_TITLE_9089 PW_LEVEL_9089  \
# 15 0       Software Developers, Applications     Level III
#    1       Software Developers, Applications     Level III
#    3  Electronics Engineers, Except Computer           NaN
# ...

# %%
len(perm_data_15)
# Out:
# 98453

# %%
len(perm_data_15[perm_data_15.duplicated()])
# Out:
# 43

# %%
perm_data_15[perm_data_15['CASE_NUMBER'] == 'A-09106-39945']
# Out:
#             CASE_NUMBER DECISION_DATE        CASE_STATUS CASE_RECEIVED_DATE  \
# 15 79705  A-09106-39945    2015-08-31             Denied         2009-04-16
# 16 66     A-09106-39945    2015-12-21  Certified-Expired         2009-04-16
#
#             EMPLOYER_NAME PW_JOB_TITLE_9089 PW_LEVEL_9089  \
# 15 79705  THE CHINA PRESS          Reporter       Level I
# 16 66     THE CHINA PRESS          Reporter       Level I
#
#          WAGE_OFFER_FROM_9089 WAGE_OFFER_UNIT_OF_PAY_9089 JOB_INFO_WORK_CITY  \
# 15 79705                 14.9                        Hour           New York
# 16 66                    14.9                        Hour           New York
#
#          JOB_INFO_WORK_STATE COUNTRY_OF_CITIZENSHIP CLASS_OF_ADMISSION
# 15 79705            NEW YORK                  CHINA               H-1B
# 16 66               NEW YORK                  CHINA               H-1B

# %%
perm_data_16 = perm_data[pd.DatetimeIndex(perm_data['DECISION_DATE']).year == 2016]
perm_data_16.head()
# Out:
#         CASE_NUMBER DECISION_DATE CASE_STATUS CASE_RECEIVED_DATE  \
# 16 3  A-07078-20668    2016-05-20   Certified         2016-02-05
#    4  A-07089-23725    2016-06-15   Certified         2016-03-16
#    5  A-07138-38271    2016-02-12   Certified         2015-09-02
#    6  A-07201-58671    2016-01-08      Denied         2007-07-20
#    7  A-07278-82866    2016-05-25      Denied         2016-02-10
#
#                             EMPLOYER_NAME  \
# 16 3         WESTERN SERVICES CORPORATION
#    4           THE UNIVERSITY OF OKLAHOMA
#    5  GENERAL ELECTRIC COMPANY (AVIATION)
#    6             IAC SEARCH & MEDIA, INC.
#    7              ADORNABLE, INCORPORATED
#
#                                       PW_JOB_TITLE_9089 PW_LEVEL_9089  \
# 16 3                           Computer Systems Analyst      Level II
#    4                                Assistant Professor       Level I
#    5  Lead Flight Test Instrumentation Engineer/Tech...      Level II
# ...

# %%
len(perm_data_16)
# Out:
# 69238

# %%
perm_data_15[perm_data_15['CLASS_OF_ADMISSION'].isnull()]

# %%
from plotly.tools import FigureFactory as FF
data_list = np.random.randn(100)
data_list.tolist()
fig = FF.create_violin(data_list, colors='#604d9e')
iplot(fig, filename='One Violin')
# Out:
# <div id="568883a7-3058-4cb3-9dd2-ed6d9cc08274" style="height: 450px; width: 600px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("568883a7-3058-4cb3-9dd2-ed6d9cc08274", [{"opacity": 0.5, "name": "", "text": ["(pdf(y), y)=(-0.06, -2.05)", "(pdf(y), y)=(-0.06, -2.00)", "(pdf(y), y)=(-0.07, -1.96)", "(pdf(y), y)=(-0.07, -1.92)", "(pdf(y), y)=(-0.08, -1.87)", "(pdf(y), y)=(-0.08, -1.83)", "(pdf(y), y)=(-0.08, -1.78)", "(pdf(y), y)=(-0.09, -1.74)", "(pdf(y), y)=(-0.09, -1.69)", "(pdf(y), y)=(-0.10, -1.65)", "(pdf(y), y)=(-0.10, -1.60)", "(pdf(y), y)=(-0.10, -1.56)", "(pdf(y), y)=(-0.11, -1.51)", "(pdf(y), y)=(-0.11, -1.47)", "(pdf(y), y)=(-0.11, -1.42)", "(pdf(y), y)=(-0.12, -1.38)", "(pdf(y), y)=(-0.12, -1.33)", "(pdf(y), y)=(-0.12, -1.29)", "(pdf(y), y)=(-0.13, -1.24)", "(pdf(y), y)=(-0.13, -1.20)", "(pdf(y), y)=(-0.13, -1.15)", "(pdf
# ...
